# %%
import pandas as a

# %%
data=a.read_csv(r"C:\Users\ADMIN\Downloads\fiat500 (1).csv")

# %%
data.head(11)
# Out:
#     ID   model  engine_power  age_in_days      km  previous_owners        lat  \
# 0    1  lounge            51          882   25000                1  44.907242
# 1    2     pop            51         1186   32500                1  45.666359
# 2    3   sport            74         4658  142228                1  45.503300
# 3    4  lounge            51         2739  160000                1  40.633171
# 4    5     pop            73         3074  106880                1  41.903221
# 5    6     pop            74         3623   70225                1  45.000702
# 6    7  lounge            51          731   11600                1  44.907242
# 7    8  lounge            51         1521   49076                1  41.903221
# 8    9   sport            73         4049   76000                1  45.548000
# 9   10   sport            51         3653   89000                1  45.438301
# 10  11     pop            51          790   43286                1  40.871429
#
#           lon  price
# ...

# %%
data.tail(11)
# Out:
#         ID   model  engine_power  age_in_days      km  previous_owners  \
# 1527  1528     pop            51          517    3000                1
# 1528  1529  lounge            51         2861  126000                1
# 1529  1530  lounge            51          731   22551                1
# 1530  1531  lounge            51          670   29000                1
# 1531  1532   sport            73         4505  127000                1
# 1532  1533     pop            51         1917   52008                1
# 1533  1534   sport            51         3712  115280                1
# 1534  1535  lounge            74         3835  112000                1
# 1535  1536     pop            51         2223   60457                1
# 1536  1537  lounge            51         2557   80750                1
# 1537  1538     pop            51         1766   54276                1
#
#             lat       lon  price
# 1527  40.748241  14.52835   9999
# 1528  43.841980  10.51531   5500
# ...

# %%
data.describe()
# Out:
#                 ID  engine_power  age_in_days             km  previous_owners  \
# count  1538.000000   1538.000000  1538.000000    1538.000000      1538.000000
# mean    769.500000     51.904421  1650.980494   53396.011704         1.123537
# std     444.126671      3.988023  1289.522278   40046.830723         0.416423
# min       1.000000     51.000000   366.000000    1232.000000         1.000000
# 25%     385.250000     51.000000   670.000000   20006.250000         1.000000
# 50%     769.500000     51.000000  1035.000000   39031.000000         1.000000
# 75%    1153.750000     51.000000  2616.000000   79667.750000         1.000000
# max    1538.000000     77.000000  4658.000000  235000.000000         4.000000
#
#                lat          lon         price
# count  1538.000000  1538.000000   1538.000000
# mean     43.541361    11.563428   8576.003901
# std       2.133518     2.328190   1939.958641
# min      36.855839     7.245400   2500.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1538 entries, 0 to 1537
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               1538 non-null   int64
#  1   model            1538 non-null   object
#  2   engine_power     1538 non-null   int64
#  3   age_in_days      1538 non-null   int64
#  4   km               1538 non-null   int64
#  5   previous_owners  1538 non-null   int64
#  6   lat              1538 non-null   float64
#  7   lon              1538 non-null   float64
#  8   price            1538 non-null   int64
# dtypes: float64(2), int64(6), object(1)
# memory usage: 108.3+ KB

# %%
data['model'].unique()
# Out:
# array(['lounge', 'pop', 'sport'], dtype=object)

# %%
data["engine_power"].unique()
# Out:
# array([51, 74, 73, 62, 63, 66, 77, 58], dtype=int64)

# %%
data["km"].unique()
# Out:
# array([ 25000,  32500, 142228, 160000, 106880,  70225,  11600,  49076,
#         76000,  89000,  43286,  17500,  18450, 120000,  40500,  28200,
#        110000,  96848,  31000,  20030,  19037,   8000,  27595,  14900,
#          9218, 124000, 100000,  28900,   4000,  59216,  99477,  21730,
#        140000,  32033, 138116,  17000,  58527,  43100,  13373, 119000,
#         28500,  83000,  98000,  12693,  14586,  27640,  49000, 107000,
#         66000,  35000,  24651,  71900,  11200, 124050,  69395,  17961,
#         18669,  22700,  56000,  22669,  50000,  39743,  27466,  22609,
#         94485, 188000,  94000,  60786,  41950,  16971,  45300,  75359,
#         12585, 103000,  77149,  13587,  55595,  17250, 145000,  20849,
#        107375,  17841,  44778,  78681, 123000,  17912,  69916,  97700,
#         11500,  12372, 165600,  28000,  86000,  18592,  41558,  96000,
#         19000,  18183,  75500,  39500, 128000,  12929, 113254,  18000,
# ...

# %%
data["previous_owners"].unique()
# Out:
# array([1, 2, 3, 4], dtype=int64)

# %%
data.shape
# Out:
# (1538, 9)

# %%
data.drop('ID',axis=1)
# Out:
#        model  engine_power  age_in_days      km  previous_owners        lat  \
# 0     lounge            51          882   25000                1  44.907242
# 1        pop            51         1186   32500                1  45.666359
# 2      sport            74         4658  142228                1  45.503300
# 3     lounge            51         2739  160000                1  40.633171
# 4        pop            73         3074  106880                1  41.903221
# ...      ...           ...          ...     ...              ...        ...
# 1533   sport            51         3712  115280                1  45.069679
# 1534  lounge            74         3835  112000                1  45.845692
# 1535     pop            51         2223   60457                1  45.481541
# 1536  lounge            51         2557   80750                1  45.000702
# 1537     pop            51         1766   54276                1  40.323410
#
#             lon  price
# 0      8.611560   8900
# ...

# %%
data1=data.drop(['ID','lat','lon'],axis=1)

# %%
data1.head(11)
# Out:
#      model  engine_power  age_in_days      km  previous_owners  price
# 0   lounge            51          882   25000                1   8900
# 1      pop            51         1186   32500                1   8800
# 2    sport            74         4658  142228                1   4200
# 3   lounge            51         2739  160000                1   6000
# 4      pop            73         3074  106880                1   5700
# 5      pop            74         3623   70225                1   7900
# 6   lounge            51          731   11600                1  10750
# 7   lounge            51         1521   49076                1   9190
# 8    sport            73         4049   76000                1   5600
# 9    sport            51         3653   89000                1   6000
# 10     pop            51          790   43286                1   8950

# %%
import seaborn as sns

# %%
x=sns.heatmap(data.corr(),annot=True)
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_4204\3912571873.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   x=sns.heatmap(data.corr(),annot=True)

# %%
data2=data.drop(['price'],axis=1)

# %%
x=a.get_dummies(data2)

# %%
x.head(3)
# Out:
#    ID  engine_power  age_in_days      km  previous_owners        lat  \
# 0   1            51          882   25000                1  44.907242
# 1   2            51         1186   32500                1  45.666359
# 2   3            74         4658  142228                1  45.503300
#
#         lon  model_lounge  model_pop  model_sport
# 0   8.61156             1          0            0
# 1  12.24189             0          1            0
# 2  11.41784             0          0            1

# %%
y=data['price']

# %%
y.head(4)
# Out:
# 0    8900
# 1    8800
# 2    4200
# 3    6000
# Name: price, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
r=LinearRegression()

# %%
reg=r.fit(x_train,y_train)

# %%
y_pred=r.predict(x_test)

# %%
y_pred
# Out:
# array([ 5819.19308766,  7248.82914153,  9741.89369742,  9798.98033087,
#        10055.00624598,  9551.49556786,  9758.01743884, 10122.97783636,
#         9654.96618159,  9251.14032569, 10478.09512262,  7807.30052547,
#         7705.15873773,  6295.632449  ,  9545.40486315, 10422.92177705,
#         9616.90811611,  7756.91711601,  4893.88454417, 10581.46142712,
#        10465.24078348, 10443.29318232,  7518.43696045, 10028.21911471,
#         6990.7311888 ,  8989.8690083 ,  4823.51364348,  6989.03118693,
#         7822.83203728,  9683.17944076,  7344.21343122,  5341.43860784,
#         5420.78405343,  5092.38401334,  8971.44357491,  5702.81242404,
#         9920.16285468,  8334.58448285,  6220.9332372 ,  8389.23958506,
#         9695.84208057,  6859.59630724,  9101.22635454, 10063.22592981,
#         8621.83915743, 10175.06753921,  9063.21918346,  8867.24865341,
#         7094.44228182,  9058.37693563,  9474.82390749, 10406.09102841,
# ...

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.8428319728463651
